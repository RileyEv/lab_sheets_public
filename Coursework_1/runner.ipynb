# %%
import lsr
print('Basic 1')
lsr.main(['train/basic_1.csv', '--plot'])
print('Basic 2')
lsr.main(['train/basic_2.csv', '--plot'])
print('Basic 3')
lsr.main(['train/basic_3.csv', '--plot'])
print('Basic 4')
lsr.main(['train/basic_4.csv', '--plot'])
print('Basic 5')
lsr.main(['train/basic_5.csv', '--plot'])
print('Noise 1')
lsr.main(['train/noise_1.csv', '--plot'])
print('Noise 2')
lsr.main(['train/noise_2.csv', '--plot'])
print('Noise 3')
lsr.main(['train/noise_3.csv', '--plot'])
print('Adv 1')
lsr.main(['train/adv_1.csv', '--plot'])
print('Adv 2')
lsr.main(['train/adv_2.csv', '--plot'])
print('Adv 3')
lsr.main(['train/adv_3.csv', '--plot'])
# Out:
# Basic 1
# Linear
# 1.0957277973519854e-27
# Basic 2
# Linear
# Linear
# 1.725475457989919e-26
# Basic 3
# Polynomial
# 2.870816594100041e-18
# Basic 4
# Linear
# Polynomial
# 9.867536024365619e-10
# Basic 5
# Sin
# 1.2682359001057163e-25
# Noise 1
# linear
# 12.207460140137108
# Noise 2
# linear
# Polynomial
# 849.5527462320334
# Noise 3
# linear
# Polynomial
# Sin
# 482.9090507852571
# Adv 1
# Polynomial
# linear
# Polynomial
# 199.72560759322522
# Adv 2
# Sin
# linear
# Sin
# 3.685132050447595
# Adv 3
# linear
# Polynomial
# Sin
# linear
# Sin
# Polynomial
# 1009.4095444890945
